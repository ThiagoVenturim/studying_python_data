# %%
import pandas as pd
try:
    df = pd.read_csv(
            'sentiment labelled sentences/amazon_cells_labelled.txt', 
            names = ['review', 'sentiment'], 
            sep='\t' 
        )
    print("Arquivo CSV Aberto")
except FileNotFoundError: 
    print("Erro ao Abrir o Arquivo CSV")
# Out:
# Arquivo CSV Aberto

# %%
print(f"Exibindo Aquivo CSV:\n{df}")
# Out:
# Exibindo Aquivo CSV:
#                                                 review  sentiment
# 0    So there is no way for me to plug it in here i...          0
# 1                          Good case, Excellent value.          1
# 2                               Great for the jawbone.          1
# 3    Tied to charger for conversations lasting more...          0
# 4                                    The mic is great.          1
# ..                                                 ...        ...
# 995  The screen does get smudged easily because it ...          0
# 996  What a piece of junk.. I lose more calls on th...          0
# 997                       Item Does Not Match Picture.          0
# 998  The only thing that disappoint me is the infra...          0
# 999  You can not answer calls with the unit, never ...          0
#
# [1000 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   review     1000 non-null   object
#  1   sentiment  1000 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 15.8+ KB

# %%
linhas, colunas =  df.shape
print(f"Linhas: {linhas}, Colunas: {colunas}")
# Out:
# Linhas: 1000, Colunas: 2

# %%
df.describe()
# Out:
#         sentiment
# count  1000.00000
# mean      0.50000
# std       0.50025
# min       0.00000
# 25%       0.00000
# 50%       0.50000
# 75%       1.00000
# max       1.00000

# %%
from sklearn.model_selection import train_test_split
try:
    reviews = df['review'].values
    sentiments = df['sentiment'].values
    reviews_train, reviews_test, sentiments_train, reviews_test = train_test_split(reviews, sentiments, test_size=0.2, random_state=500)
    print("Conjunto de treino e teste sepados ")
except Exception:
    print("Erro ao separar conjunto de treino e teste")
# Out:
# Conjunto de treino e teste sepados
